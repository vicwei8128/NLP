# %% [markdown]
# # 蒐集新聞頁面連結

# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import re


new_list = []

url = 'https://money.udn.com/money/index'

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
#print(response.text)
div_tag = soup.find('div', {'id':'tab1'})

soup2 = BeautifulSoup(str(div_tag), 'html.parser')
a_tags = soup2.find_all('a')

for i in a_tags:
    print('title: {}, link: {}'.format(i.text, 'https://money.udn.com'+i['href']))
    new_list.append('https://money.udn.com'+i['href'])
# Out:
# title: 13:21國防院：日本因應新型態戰爭  積極參加多國演習, link: https://money.udn.com/money/story/7307/5626134?from=edn_breaknewstab_index
# title: 13:07網球／敗給「世界第5」德國好手 盧彥勳選手生涯謝幕, link: https://money.udn.com/money/story/5648/5626024?from=edn_breaknewstab_index
# title: 13:0626日起汽油降2角、柴油漲1角 維持亞鄰最低價, link: https://money.udn.com/money/story/5618/5626105?from=edn_breaknewstab_index
# title: 13:06抗議反同新法  布達佩斯萬人遊行挺LGBTQ, link: https://money.udn.com/money/story/10511/5626103?from=edn_breaknewstab_index
# title: 13:06出席海地前總統葬禮  古文劍會晤美駐聯大使, link: https://money.udn.com/money/story/7307/5626100?from=edn_breaknewstab_index
# title: 13:00蔡總統：疫苗接種進度 提前破25%目標, link: https://money.udn.com/money/story/5612/5626055?from=edn_breaknewstab_index
# title: 12:54看不懂東奧開幕式成中國熱議話題 台灣也被波及, link: https://money.udn.com/money/story/5603/5626043?from=edn_breaknewstab_index
# title: 12:54焚風影響台東太麻里飆40度  全台11縣市防高溫, link: https://money.udn.com/money/story/5621/5626045?from=edn_breaknewstab_index
# title: 12:46烟花已登陸浙江舟山  陸發布首個風暴潮和海浪雙紅預警, link: https://money.udn.com/money/story/5604/5626033?from=edn_breaknewstab_index

# %% [markdown]
# # 爬取新聞文章及圖片

# %%
from time import sleep
import os
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

        
def save_news(url):
    
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}

    response = requests.get(url, headers=headers)
    sleep(1)
    soup = BeautifulSoup(response.text, 'html.parser')
    new_title = soup.find_all('h2',{'id':'story_art_title'})

    save_path = './news/'+new_title[0].text.replace(':','')
    
    article_body = soup.find_all('div',{'id':'article_body'})
    print('new title: {}'.format(new_title[0].text))

    ## create folder
    createFolder(save_path)
    soup2 = BeautifulSoup(str(article_body[0]), 'html.parser')


    ## save article contens in folder
    with open(save_path+'/contents.txt', 'w', encoding='utf-8') as f:  
        p_tags = soup2.find_all('p')
        print('new content: ')
        for i in p_tags:
            print(i.text)
            f.write(i.text)

    ## save image in article        
    img_tags = soup2.find_all('img')
    print('save image: ')
    for i in img_tags:
        print(i['src'])
        urlretrieve(i['src'], save_path+'/'+i['title']+'.jpg')
    print('==========\n\n')
    

for new_url in new_list:
    print(new_url)
    save_news(new_url)
# Out:
# https://money.udn.com/money/story/7307/5626134?from=edn_breaknewstab_index
# new title: 國防院：日本因應新型態戰爭  積極參加多國演習
# new content:
# 國防部智庫、國防院指出，日本防衛省剛公布的2021年版防衛白皮書，不僅載明台灣局勢穩定對日本安全的重要，更強調應建構「多次元統合防衛力」，以因應來自太空、網路、電磁領域新作戰型態挑戰。
#
# 國防部智庫、國防安全研究院發布最新一篇「國防安全即時評析」，網路安全與決策推演研究所助理研究員杜貞儀以「日本防衛白皮書揭示新型態戰爭」為題，分析未來的新作戰方式。
#
# 杜貞儀指出，日本防衛省於13日公布2021年版防衛白皮書，公開說明日本目前的整體安全環境、國防政策，及對重大問題外交立場，不僅首度載明台灣局勢穩定對於日本安全及國際社會穩定的重要性，更強調需整合建構「多次元統合防衛力」，以因應來自太空、網路、電磁領域新作戰型態的挑戰。
#
# 杜貞儀表示，所謂「多次元統合防衛力」，是透過強化太空、網路、電磁戰力，推動陸海空自衛隊聯合作戰的統一指揮及運用，以跨領域（日文稱「領域橫斷」，即cross-domain）作戰發揮聯合戰力，進行積極防衛，阻止並排除對日本的攻擊。
#
# 為因應新型態戰爭挑戰，日本近年積極參加各項大型多國演習，推展國際安全合作。2021防衛白皮書透露，日本今年已首次正式參加由北約卓越聯合網路防禦中心（NATO Cooperative Cyber Defence Centre ofExcellence, NATO CCDCOE）舉辦的年度「鎖盾」（Locked Shield）網路防禦演練（cyber defenseexercise），此演練包括技術攻防與決策演練兩部分，採同步進行。
#
# 杜貞儀指出，日本先前在2019年參與的NATOCCDCOE年度演練「網路聯盟」（Cyber Coalition），演練重點則為北約各國因應網路威脅的合作機制，因此持續參與北約各項演練，顯示日本與北約各國實質網路安全合作的進一步深化。
#
# 太空部分，2021防衛白皮書同樣提及目前由美太空軍司令部主辦的「施里弗兵推」（Schriever Wargame）。自2018年日本開始每年參與「施里弗兵推」，連同五眼聯盟國家及德、法兩國，以桌上兵推的方式共同探討如何透過太空領域釋放戰略訊息。
#
# 雖然「施里弗兵推」實際具體內容列為機密，不對外公開，但在防衛白皮書公布前的7月6日，日本防衛省所屬政策智庫防衛研究所發布一份評析，由「施里弗兵推」唯一可公開取得的2012年份報告，試圖分析如何藉由兵推，了解跨領域作戰的態勢及未來戰爭樣貌。
#
# 杜貞儀說明，文中特別提到，在2012年「施里弗兵推」中，其背景設定將太空與網路領域的緊急應變及指揮管制體系整合為單一機關，並以此進行兵推驗證，此構想極具參考價值，建議未來美日同盟或以美國為中心的印太同盟，或可就此進行更多兵推探討，因此日本可能藉此報告揭示對新型態戰爭的研究方向之一，未來發展值得持續關注。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5648/5626024?from=edn_breaknewstab_index
# new title: 網球／敗給「世界第5」德國好手 盧彥勳選手生涯謝幕
# new content:
# 盧彥勳在東奧的第一球場迎接生涯第5度奧運。特派記者余承翰／攝影facebook
#
# 我國奧運「五朝元老」盧彥勳，選手生涯最終章，首輪將就強碰東奧列男單第4種子、世界排名第5的德國好手澤瑞夫 （Alexander Zverev），盧彥勳奮戰全場但以1：6、3：6出局。
#
#
#
# 37歲的盧彥勳年長澤瑞夫13歲，兩人過去曾在ATP千分名人賽兩度碰頭，雙方各拿1勝，不過盧彥勳奪勝已要回溯到2016年，2017年邁阿密名人賽後就再沒交手紀錄。
#
#
#
# 盧彥勳哥哥盧威儒分享說，和澤瑞夫兄弟結識許久，今年溫布頓還和澤瑞夫一起聊過大會特別設的台灣便當攤位，沒想到如此有緣，弟弟東奧就在第一輪碰到這位新生代好手。
#
#
#
# 兩名不同世代的好手，今天在有明網球公園的第一球場碰頭，198公分的澤瑞夫今天發揮發球優勢，首盤完全保發外，一下場就破盧彥勳發球局，花不到半小時就以6：1先下一城；第二盤前3個發球局再發出4記「愛司」，第6局破發成功後，第7局再連送2記「愛司」，最終就以6：3迎接勝利。盧彥勳在東奧的第一球場迎接生涯第5度奧運。特派記者余承翰／攝影facebook
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/25/realtime/13120142.jpeg&s=Y&x=0&y=24&sw=1280&sh=720&sl=W&fw=1050&exp=3600&exp=3600
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/25/realtime/13120141.jpeg&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
#
#
# https://money.udn.com/money/story/5618/5626105?from=edn_breaknewstab_index
# new title: 26日起汽油降2角、柴油漲1角 維持亞鄰最低價
# new content:
# 台灣中油表示，26日凌晨零時起，汽油每公升調降0.2元、柴油則吸收0.5元調幅，調漲0.1元。調降後95無鉛汽油每公升29.9元，油價持續維持亞鄰最低價。
#
# 26日起，92無鉛汽油每公升28.4元、95無鉛汽油每公升29.9元、98無鉛汽油每公升31.9元、超級柴油每公升25.8元。本週油價持續維持亞洲鄰近國家最低價機制，柴油吸收0.5元。
#
# 中油表示，本週因浮動油價調整原則的調價指標7D3B週均價下跌，汽油每公升調降0.2元，調降後95無鉛汽油每公升29.9元，未達啟動油價平穩措施門檻。
#
# 至於柴油，因調降後的換算零售價高於前週公告參考零售價格，本來每公升應調漲0.6元，考量民生與產業，維持價格需低於亞洲鄰近國家（日、韓、港、星）的限制，由台灣中油吸收部分調幅，柴油本週吸收0.5元，實際價格每公升調漲0.1元；累計110年至6月底止，中油共吸收44.35億元。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/10511/5626103?from=edn_breaknewstab_index
# new title: 抗議反同新法  布達佩斯萬人遊行挺LGBTQ
# new content:
# 匈牙利總理奧班（Viktor Orban）一連串反同性戀舉措掀起反彈，局勢劍拔弩張，今天有成千上萬名民眾走上街頭，力挺布達佩斯規模最大的同志驕傲遊行。
#
# 匈牙利國會上月通過「反戀童法」（anti-paedophilia law）之後，海內外批評人士一致指控奧班將同性戀和戀童癖混為一談。
#
# 布達佩斯同志驕傲遊行（Budapest Pride）策劃組織發言人梅吉希克（Johanna Majercsik）告訴法新社說：「許多人對這項新法及反同宣傳感到氣餒。」
#
# 梅吉希克說：「他們要展現對LGBTQ（同性戀、雙性戀、跨性別及酷兒）團體的支持。」並說，今年的驕傲遊行規模是26年來最大的。
#
# 根據法新社攝影記者所述，超過1萬人參加了這場彩虹遊行，隊伍沿著一條主要大道前行，最後越過多瑙河（Danube）在一座公園結束行動。
#
# 儘管奧班說這項法案是在保護兒童，多位LGBTQ領袖說，此法是在污名化LGBTQ群體，意在明年大選前鞏固激進右派對總理的支持。
#
# 遊行民眾中，兩個孩子的母親、46歲的瓦拉迪（Zsofi Varadi）表示：「以前我不曾參加驕傲遊行，但我一向支持LGBTQ族群 ，也了解他們面臨的各項問題…但今年我真的生氣了，居然有這麼多不利他們的宣傳，他們需要看到有很多人支持他們。」接著瓦拉迪套上一件象徵LGBTQ的彩虹T恤，跟著和平遊行隊伍往前行。
#
# 沿途一些建物的陽台懸掛著彩虹旗，而遊行民眾也舉著牌子，嘲弄奧班和推動立法的執政青年民主黨（Fidesz）。
#
# 歐洲聯盟執行委員會（European Commission）針對匈牙利這項新法採取法律行動後，奧班21日表示，將舉辦公投以了解國內民眾對此法的支持度。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/7307/5626100?from=edn_breaknewstab_index
# new title: 出席海地前總統葬禮  古文劍會晤美駐聯大使
# new content:
# 遇刺身亡的海地前總統摩依士葬禮23日舉行，駐海地大使古文劍代表政府出席，他在推特（Twitter）推文說，很高興與美國駐聯合國大使湯瑪斯-葛林斐德就共同致力應對未來挑戰交換意見。
#
# 古文劍推文附上與湯瑪斯-葛林斐德（LindaThomas-Greenfield）握手的照片。
#
# 湯瑪斯-葛林斐德1月曾在參院聽證會上表示，台灣是區域最強健民主政體之一，美國需要支持台灣並提供抵抗中國所需安全協助，她也會致力在聯合國反制中國。
#
# 參加摩依士（Jovenel Moise）葬禮的美國代表團，是由湯瑪斯-葛林斐德率領，由於葬禮舉行當天，儀式舉辦地附近傳出槍響，知情人士說，由於有安全疑慮，代表團比原先預期的時間還要早返國。
#
# 白宮新聞秘書莎琪（Jen Psaki）23日對媒體說：「葬禮外頭驚傳槍響，總統代表團全數平安。」
#
# 她又說：「我們很擔憂海地的動盪局勢。」
#
# 湯瑪斯-葛林斐德在推特說：「海地人民值得享有民主、穩定、安全與繁榮，在這個危機時刻，我們與他們站在一起。」
#
# 她還說，美方與海地領導階層談過話，「我們敦促每個人和平表達意見，不要訴諸於暴力」。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5612/5626055?from=edn_breaknewstab_index
# new title: 蔡總統：疫苗接種進度 提前破25%目標
# new content:
# 蔡總統今（25）日宣布，全國疫苗接種累計已經超過634萬人次，接種人口涵蓋率，亦即至少打過一劑疫苗的人口比例，來到26.05%，劑次人口比則來到27.02%，均達成原先設定七月底破25%的目標。
#
#
#
# 對於新冠肺炎疫苗接種進度，蔡總統在臉書發文指出，在大家密切關注東京奧運賽事的同時，她要向報告全國疫苗接種的進度。
#
#
#
# 蔡總統說明，截至目前為止，全國的疫苗接種累計已經超過634萬人次，接種人口涵蓋率（至少打過一劑疫苗的人口比例）來到26.05%，劑次人口比則來到27.02%，都達成了原先設定七月底破25%的目標，比預期更早。
#
#
#
# 蔡總統對國人感謝，踴躍登記意願，依序預約接種，保護自己也保護親友，接下來，政府會持續取得疫苗、持續進行接種，讓台灣社會的集體防護力不斷上升。
#
#
#
# 蔡總統也提醒全國疫情警戒即將7月27日（周二）調降為二級。降級不鬆懈，在家看奧運最安全，若要出門，也請記得嚴格落實戴口罩、實聯制、保持社交距離等防疫措施。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5603/5626043?from=edn_breaknewstab_index
# new title: 看不懂東奧開幕式成中國熱議話題 台灣也被波及
# new content:
# 東京奧運23日正式開幕，中國大批網友稱看不懂開幕式表演，部分反映疫情下運動員處境、悼念疫情死者的橋段甚至被酸「充斥陰間氣息」。相關的話題在微博上有近億次的閱讀量。
#
# 此外，開幕式中日本NHK以台灣稱呼中華隊、美國NBC引用的中國地圖不含台灣，也都成開幕式的「罪狀」。
#
# 東京奧運正式開幕後，除了關注運動員的表現外，中國網友不忘熱烈討論東奧開幕式上的各項表演橋段。在微博上，標記為「東京奧運會開幕式迷惑行為」的話題有近億次的閱讀量。
#
# 根據德國之聲報導，這些來自中國網友的批評不乏「東京奧運會開幕式上有哪些讓人看不懂的細節」、「東京奧運會開幕式，史上最慘奧運會」等等，甚至將開幕式稱為「開墓式」，並稱「藝術可以接地氣，但請不要接地府」。
#
# 據報導，中國網友點名陰間氣息濃厚的橋段包含，「反映疫情之下運動員處境艱難」、「悼念因疫情失去生命的人們」的舞蹈。
#
# 然而報導分析，這些表演顯示這次東京奧運的開幕式嘗試建構人文關懷，不但安排了為全世界的COVID-19死者默哀，並將與病毒對抗的心理歷程形象化，用肢體語言和舞台效果表現出人們在面對病毒侵襲時的「脆弱和堅強」、「悲觀與樂觀」、「絕望與希望」。
#
# 在中國網友群起攻之的情形下，也有人發現部分討論引用的資料、圖片並非來自於本屆奧運開幕式，因此投入「事實查核」工作，釐清在社群平台上的錯誤資訊。
#
# 中國問答社群平台上，有用戶發起「被誤解的奧運會開幕式，被營銷號掌控的互聯網情緒」一文，除了整理部分被移花接木成東京奧運開幕式的表演橋段，並說明出處外，也點出許多網友或許根本就沒有看開幕式，僅僅藉由營銷號（以行銷為目的的資訊發布帳號）提供的資訊，並沒有經過更多的思考，根據評論的風向就形成了對開幕式的印象。
#
# 然而這樣的「澄清」與「批評」顯然不被接受，這篇文章下又遭大量的中國網友洗版、攻擊。
#
# 除了開幕式的節目外，在選手進場的安排，也引起中國輿論不滿。包含日本NHK以台灣稱呼中華隊、美國全國廣播公司（NBC）介紹中國隊入場時使用的中國地圖未包含台灣，都成罪狀。
#
# 除了中共官媒環球時報直指這是日本故意「做手腳」，呼籲中方應與NHK交涉，中國駐紐約總領館在24日以「駐紐約總領館發言人」名義發出聲明，稱NBC的行為影響十分惡劣，傷害了中國人民的尊嚴和情感。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5621/5626045?from=edn_breaknewstab_index
# new title: 焚風影響台東太麻里飆40度  全台11縣市防高溫
# new content:
# 中央氣象局今天中午更新高溫資訊，東南部地區已有焚風發生，花東預估達攝氏38度以上為橙色燈號，台東太麻里上午近12時已出現40度；北北基桃等9縣市防36度以上高溫。
#
# 氣象局更新高溫資訊，西南風沉降影響，天氣晴朗炎熱，東南部地區已有焚風發生。今天白天花蓮縣縱谷，台東縣地區為橙色燈號，可能有38度極端高溫出現；台北市、新北市、基隆市、新竹市、金門縣地區，桃園市、新竹縣、苗栗縣、宜蘭縣近山區或河谷為黃色燈號，預估氣溫達36度以上。
#
# 根據氣象局網站，上午11時42分台東縣太麻里鄉出現40度高溫，台東鹿野39.3度居次；前5名都位於台東，達37.7度以上；前10名中，花蓮、台北、新北等也都上榜。
#
# 高溫橙燈區域為花蓮縣、台東縣；高溫黃燈為基隆市、台北市、新北市、桃園市、新竹縣市、苗栗縣、宜蘭縣、金門縣。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5604/5626033?from=edn_breaknewstab_index
# new title: 烟花已登陸浙江舟山  陸發布首個風暴潮和海浪雙紅預警
# new content:
# 根據浙江省氣象服務中心官方微博消息，今年第6號颱風烟花，已於25日12時30分前後，登陸舟山普陀區，登陸時強度為颱風級，中心氣壓965百帕，中心最大風速38公尺/秒。
#
#
#
# 另據央視稍早報導，大陸氣象台繼續發布颱風橙色預警。大陸國家海洋預報台繼續發布了風暴潮和海浪的紅色預警，這是大陸今年首個風暴潮和海浪雙紅色預警。
#
#
#
# 浙江、福建等地多措並舉加強防範，全力應對颱風烟花可能帶來的影響。
#
#
#
# 此外，受颱風影響，上海浦東和虹橋機場今日全日進出港航班全部取消。上海機場和航空公司提醒旅客及時合理安排出行，可透過航空公司或機場服務熱線、官網等查詢。大陸發布首個風暴潮和海浪雙紅預警。央視新聞畫面facebook
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/25/realtime/13120159.jpg&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
